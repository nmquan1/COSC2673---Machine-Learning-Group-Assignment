# %% [markdown]
# # Step 4: Model Exploration and Optimization

# %%
#import basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import seaborn as sns

#image and output formatting
import PIL
from PIL import Image
from tabulate import tabulate

#dir manip libraries
import os, sys, glob, pathlib, tempfile
from pathlib import Path

#import label encoding
from sklearn.preprocessing import LabelEncoder

#keras for model output customization
import keras
from keras import layers, ops

#tensorflow tools for model building
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout, Rescaling, Activation
from tensorflow.keras.optimizers import Adam, SGD


# Custom functions (this works, finally)
from pyTools.utils import *
from pyTools.preprocess import *
from pyTools.predict import *

# Print out versions for important tools
print("Pandas version:", pd.__version__)
print("TensorFlow version:", tf.__version__)
print("Pillow version:", PIL.__version__)
# Out:
# Pandas version: 2.1.4
# TensorFlow version: 2.16.1
# Pillow version: 10.2.0

# %%
# Define the path to your Google Drive folder containing the images
data_dir = Path("../ML_Asm2_ProjFiles/preview")

# Ensure the directory exists
if not data_dir.exists():
    raise ValueError(f"Directory {data_dir} does not exist. Please check the path.")

# %%
data = labeled_by_shape(data_dir)
# Out:
# Found 19825 files belonging to 5 classes.

# %%
first_batch = next(iter(data))
images, labels = first_batch
images = images / 255.0
pixel_sum = np.zeros((img_height, img_width), dtype=float)

for img in images:
    pixel_sum += img.numpy().squeeze()  # .squeeze() to remove single-channel dimension
    
pixel_mean = pixel_sum / images.shape[0]
plt.figure(figsize=(10, 7))
sns.heatmap(pixel_mean, cmap='viridis')
plt.gca().invert_yaxis()  # This line reverses the y-axis direction
plt.title('Pixel Intensity Distribution Heatmap (First Batch)')
plt.show()

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# ***compile()***:
#   - ***optimizer***: Stochastic Gradient Descent, **Adoptive Moment Estimator(Adam)**
#   - ***loss***: **Categorical (Focal) Cross Entropy**
#   - ***metrics***: **(Categorical) Accuracy**, Top K Categorical, Categorical Cross Entropy, F1/Precision/Recall, AUC, IoU, MeanIoU
#
# Initial design for baseline model.
# Our goal was to design a simple Multilayer Perceptron baseline that utilizes keras libraries and utilities. Partially because of keras's versatility as a highly customisable tool, this model poses as a milestone for us to implement different modifications and tunings in development in the next steps.

# %%
# Define your model
CNN_Prototype1 = Sequential([
    tf.keras.Input(shape=(28, 28, 1)),
    tf.keras.layers.Rescaling(1./255),
    Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')
])

# Compile the model
CNN_Prototype1.compile (
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy']
)

# Train the model
hist = CNN_Prototype1.fit(
    train,
    epochs=5,
    batch_size=150,
    validation_data=val
)
# Out:
# Epoch 1/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 15s 186ms/step - loss: 1.2504 - sparse_categorical_accuracy: 0.5283 - val_loss: 0.5069 - val_sparse_categorical_accuracy: 0.8683
# Epoch 2/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.4800 - sparse_categorical_accuracy: 0.8703 - val_loss: 0.3766 - val_sparse_categorical_accuracy: 0.8827
# Epoch 3/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 0.3526 - sparse_categorical_accuracy: 0.8972 - val_loss: 0.2945 - val_sparse_categorical_accuracy: 0.9065
# Epoch 4/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 0.2920 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.2706 - val_sparse_categorical_accuracy: 0.9165
# Epoch 5/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.2471 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.2419 - val_sparse_categorical_accuracy: 0.9153

# %%
# Evaluate the model
loss, accuracy = CNN_Prototype1.evaluate(test)
print("Test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2237 - sparse_categorical_accuracy: 0.9161
# Test loss: 0.2217147797346115
# Test accuracy: 0.9172602891921997

# %%
CNN_Prototype1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 28, 28, 16)          │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 3, 3, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 288)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          36,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 155,057 (605.70 KB)
#  Trainable params: 51,685 (201.89 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 103,372 (403.80 KB)

# %%
keras.utils.plot_model(CNN_Prototype1, show_shapes=True)

# %%
# Extract loss and metric values
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
train_metric = hist.history['sparse_categorical_accuracy']
val_metric = hist.history['val_sparse_categorical_accuracy']

# Plot the learning curve
plot_learning_curve(train_loss, val_loss, train_metric, val_metric, metric_name='Accuracy')

# %%
vResults_tf(CNN_Prototype1, val, data.class_names)

# %%
vResults_tf(CNN_Prototype1, test, data.class_names)

# %%
trueData = Path("../ML_Asm2_ProjFiles/tsrd-train")

# %%
image_count = len(list(trueData.glob('*.png')))
print(image_count)
# Out:
# 4170

# %%
external_dir = "../ML_Asm2_ProjFiles/Test"  # Path to your dataset
raw_data = []

# Loop through all image files in the specified directory
for img_file in os.listdir(external_dir):
    if img_file.endswith((".png", ".jpg", ".jpeg", ".bmp")):
        # Get the full path to the image
        img_path = os.path.join(external_dir, img_file)
        
        # Preprocess the image using the defined function
        preprocessed_img = preprocess28(img_path)
        
        # Add the preprocessed image to the raw_data list
        raw_data.append(preprocessed_img)

# Shuffle the images to randomize the order
random.shuffle(raw_data)

# Convert the list to a NumPy array
raw_data = np.array(raw_data)

# %%
vResults_raw(CNN_Prototype1, raw_data, data.class_names)

# %% [markdown]
# # Notes:
#     Baseline model:
#      - Strength:
#      1. Classify data in the same dataset with very high accuracy.
#      2. Not computationally expensive
#
#      - Weakness:
#      1. Inconsistent output metrics in each epoch.
#      2. Poor classification for external data
#         -> Cause: Overfitting, Rudimentary Model.
#
#     Conclusion: Although the model did not perform well on external data, it reached a certain degree of generalization, which is fairly enough for this stage.

# %%
Enhanced_CNN = Sequential([
    tf.keras.Input(shape=(28, 28, 1)),
    Rescaling(1./255),
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')
])

Enhanced_CNN.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy']
)

# Model Summary
Enhanced_CNN.summary()

# Train the model
hist = Enhanced_CNN.fit(
    train,
    epochs=25,
    batch_size=32,
    validation_data=val
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 7, 7, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 5)                   │           1,285 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 390,021 (1.49 MB)
#  Trainable params: 389,573 (1.49 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 13s 131ms/step - loss: 1.3350 - sparse_categorical_accuracy: 0.6566 - val_loss: 2.9289 - val_sparse_categorical_accuracy: 0.1972
# Epoch 2/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - loss: 0.3156 - sparse_categorical_accuracy: 0.8902 - val_loss: 4.2787 - val_sparse_categorical_accuracy: 0.2065
# Epoch 3/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - loss: 0.2335 - sparse_categorical_accuracy: 0.9168 - val_loss: 5.7310 - val_sparse_categorical_accuracy: 0.2045
# Epoch 4/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - loss: 0.1809 - sparse_categorical_accuracy: 0.9376 - val_loss: 6.3918 - val_sparse_categorical_accuracy: 0.2183
# Epoch 5/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - loss: 0.1577 - sparse_categorical_accuracy: 0.9431 - val_loss: 7.1707 - val_sparse_categorical_accuracy: 0.3760
# Epoch 6/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - loss: 0.1217 - sparse_categorical_accuracy: 0.9568 - val_loss: 4.8611 - val_sparse_categorical_accuracy: 0.4295
# Epoch 7/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - loss: 0.1144 - sparse_categorical_accuracy: 0.9570 - val_loss: 3.6927 - val_sparse_categorical_accuracy: 0.4712
# Epoch 8/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - loss: 0.0921 - sparse_categorical_accuracy: 0.9674 - val_loss: 1.6933 - val_sparse_categorical_accuracy: 0.6200
# Epoch 9/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.2620 - val_sparse_categorical_accuracy: 0.9302
# Epoch 10/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - loss: 0.0721 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.2246 - val_sparse_categorical_accuracy: 0.9342
# Epoch 11/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.1673 - val_sparse_categorical_accuracy: 0.9575
# Epoch 12/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - loss: 0.0605 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 0.9765
# Epoch 13/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - loss: 0.0585 - sparse_categorical_accuracy: 0.9805 - val_loss: 0.0899 - val_sparse_categorical_accuracy: 0.9768
# Epoch 14/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - loss: 0.0528 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9735
# Epoch 15/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.0760 - val_sparse_categorical_accuracy: 0.9753
# Epoch 16/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - loss: 0.0411 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.0536 - val_sparse_categorical_accuracy: 0.9830
# Epoch 17/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.0450 - val_sparse_categorical_accuracy: 0.9862
# Epoch 18/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.0477 - val_sparse_categorical_accuracy: 0.9835
# Epoch 19/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0619 - val_sparse_categorical_accuracy: 0.9825
# Epoch 20/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.0342 - val_sparse_categorical_accuracy: 0.9905
# Epoch 21/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.0325 - val_sparse_categorical_accuracy: 0.9900
# Epoch 22/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - loss: 0.0245 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0509 - val_sparse_categorical_accuracy: 0.9887
# Epoch 23/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - loss: 0.0213 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0273 - val_sparse_categorical_accuracy: 0.9915
# Epoch 24/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0340 - val_sparse_categorical_accuracy: 0.9893
# Epoch 25/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0679 - val_sparse_categorical_accuracy: 0.9820

# %%
# Extract loss and metric values
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
train_metric = hist.history['sparse_categorical_accuracy']
val_metric = hist.history['val_sparse_categorical_accuracy']

# Plot the learning curve
plot_learning_curve(train_loss, val_loss, train_metric, val_metric, metric_name='Accuracy')

# %%
vResults_tf(Enhanced_CNN, val, data.class_names)

# %%
vResults_raw(Enhanced_CNN, raw_data, data.class_names)

# %%
VGG_CNN = Sequential([
    tf.keras.Input(shape=(28, 28, 1)),
    Rescaling(1./255),
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')
])

VGG_CNN.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy']
)

# Model Summary
VGG_CNN.summary()

# Train the model
hist = VGG_CNN.fit(
    train,
    epochs=25,
    batch_size=128,
    validation_data=val
)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)              │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 28, 28, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 14, 14, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 7, 7, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │         590,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │           2,565 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 879,333 (3.35 MB)
#  Trainable params: 879,333 (3.35 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 14s 152ms/step - loss: 1.0995 - sparse_categorical_accuracy: 0.5488 - val_loss: 0.3051 - val_sparse_categorical_accuracy: 0.8988
# Epoch 2/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - loss: 0.3181 - sparse_categorical_accuracy: 0.8989 - val_loss: 0.1988 - val_sparse_categorical_accuracy: 0.9360
# Epoch 3/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - loss: 0.2000 - sparse_categorical_accuracy: 0.9322 - val_loss: 0.1555 - val_sparse_categorical_accuracy: 0.9475
# Epoch 4/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - loss: 0.1410 - sparse_categorical_accuracy: 0.9495 - val_loss: 0.1132 - val_sparse_categorical_accuracy: 0.9585
# Epoch 5/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - loss: 0.1048 - sparse_categorical_accuracy: 0.9636 - val_loss: 0.1057 - val_sparse_categorical_accuracy: 0.9632
# Epoch 6/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 0.0983 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0833 - val_sparse_categorical_accuracy: 0.9720
# Epoch 7/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 0.0584 - sparse_categorical_accuracy: 0.9811 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9735
# Epoch 8/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0620 - val_sparse_categorical_accuracy: 0.9793
# Epoch 9/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - loss: 0.0335 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9753
# Epoch 10/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 0.0283 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0416 - val_sparse_categorical_accuracy: 0.9847
# Epoch 11/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0579 - val_sparse_categorical_accuracy: 0.9803
# Epoch 12/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0775 - val_sparse_categorical_accuracy: 0.9805
# Epoch 13/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0518 - val_sparse_categorical_accuracy: 0.9845
# Epoch 14/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0502 - val_sparse_categorical_accuracy: 0.9850
# Epoch 15/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0467 - val_sparse_categorical_accuracy: 0.9855
# Epoch 16/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0268 - val_sparse_categorical_accuracy: 0.9900
# Epoch 17/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0620 - val_sparse_categorical_accuracy: 0.9847
# Epoch 18/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0327 - val_sparse_categorical_accuracy: 0.9908
# Epoch 19/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0369 - val_sparse_categorical_accuracy: 0.9898
# Epoch 20/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0929 - val_sparse_categorical_accuracy: 0.9707
# Epoch 21/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - loss: 0.0303 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.0377 - val_sparse_categorical_accuracy: 0.9890
# Epoch 22/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0384 - val_sparse_categorical_accuracy: 0.9900
# Epoch 23/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0517 - val_sparse_categorical_accuracy: 0.9865
# Epoch 24/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0391 - val_sparse_categorical_accuracy: 0.9908
# Epoch 25/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0358 - val_sparse_categorical_accuracy: 0.9923

# %%
# Extract loss and metric values
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
train_metric = hist.history['sparse_categorical_accuracy']
val_metric = hist.history['val_sparse_categorical_accuracy']

# Plot the learning curve
plot_learning_curve(train_loss, val_loss, train_metric, val_metric, metric_name='Accuracy')

# %%
vResults_tf(VGG_CNN, val, data.class_names)

# %%
vResults_raw(VGG_CNN, raw_data, data.class_names)
